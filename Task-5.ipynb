# %% [markdown]
# ### Task 5

# %%
import pandas as pd
 
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Load dataset
df = pd.read_csv("insurance_fraud_cleaned_final.csv")

# %%
df
# Out:
#        claim_number  age_of_driver  gender  marital_status  safety_rating  \
# 0            414724       0.357143       1               1          0.568
# 1            269568       0.250000       1               1          0.552
# 2            974592       0.214286       1               1          0.616
# 3            995328       0.607143       0               1          0.888
# 4           1140480       0.392857       1               1          0.792
# ...             ...            ...     ...             ...            ...
# 11983     621727488       0.267857       1               1          0.808
# 11984     621810432       0.821429       0               1          0.952
# 11985     621872640       0.803571       0               1          0.792
# 11986     621914112       0.267857       0               1          0.520
# 11987     621955584       0.464286       1               1          0.376
#
#        annual_income  high_education  address_change  property_status  \
# 0           0.429934               1               0                0
# 1           0.000000               0               1                0
# 2           1.000000               1               1                0
# 3           0.908032               0               1                0
# 4           0.455273               1               0                0
# ...              ...             ...             ...              ...
# 11983       0.682961               1               1                1
# 11984       0.000000               1               0                1
# 11985       0.682961               0               1                0
# 11986       1.000000               1               0                0
# 11987       0.824323               1               0                1
#
#        zip_code  ...  total_claim  injury_claim  policy deductible  \
# 0         50048  ...     0.484083      0.484981                0.4
# 1         50006  ...     0.485576      0.742631                1.0
# 2         15021  ...     0.255548      0.281299                0.4
# 3         85027  ...     0.368868      0.529316                0.0
# 4         80046  ...     0.642305      0.379336                0.4
# ...         ...  ...          ...           ...                ...
# 11983     20134  ...     0.642759      0.619605                0.4
# 11984     20134  ...     0.485792      0.315672                0.0
# 11985     20142  ...     0.491784      0.697706                1.0
# 11986     20109  ...     0.272527      0.358279                0.4
# 11987     15044  ...     0.487959      0.488715                0.0
#
#        annual premium  days open  form defects  fraud reported  claim_day  \
# 0            0.644443   0.442501             5               0         12
# 1            0.651774   0.592340             5               1         18
# 2            0.472201   0.401122             3               0         23
# 3            0.064735   0.507580             4               0         25
# 4            0.462670   0.619710             2               0          4
# ...               ...        ...           ...             ...        ...
# 11983        0.823569   0.859619             3               0         10
# 11984        0.352784   0.561709             6               1         24
# 11985        0.436111   0.414492             2               0         19
# 11986        0.910109   0.625760             5               0          7
# 11987        0.499705   0.494550             4               0         23
#
#        claim_month  claim_year
# 0                8        2023
# 1               10        2024
# 2               12        2023
# 3                2        2024
# 4                9        2024
# ...            ...         ...
# 11983            6        2024
# 11984            7        2023
# 11985            7        2024
# 11986            3        2024
# 11987            6        2024
#
# [11988 rows x 31 columns]

# %%
X = df.drop(columns=["claim_number", "fraud reported"])
y = df["fraud reported"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ### Logistic

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(max_iter=1000, random_state=42)

logistic_model.fit(X_train, y_train)

print("Train Score:", logistic_model.score(X_train, y_train))
print("Test Score:", logistic_model.score(X_test, y_test))
# Out:
# Train Score: 0.7748696558915537
# Test Score: 0.780650542118432

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

model.fit(X_train, y_train)

train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)

print("Train Score:", train_score)
print("Test Score:", test_score)
# Out:
# Train Score: 1.0
# Test Score: 0.6755629691409508

# %%
model = DecisionTreeClassifier(max_depth=5, random_state=42)

model.fit(X_train, y_train)

print("Train Score:", model.score(X_train, y_train))
print("Test Score:", model.score(X_test, y_test))
# Out:
# Train Score: 0.7795620437956204
# Test Score: 0.7827356130108424

# %% [markdown]
# ### BOOTSTRAP

# %% [markdown]
# ### for checking How realibe our model result

# %%
from sklearn.utils import resample

# %%
X_sample, y_sample = resample(
    X_train,
    y_train,
    replace=True,
    random_state=42
)

# %%
model.fit(X_sample, y_sample)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
score = model.score(X_test, y_test)

print("Bootstrap Score:", score)
# Out:
# Bootstrap Score: 0.7768974145120934

# %% [markdown]
#  #### Advanced Models

# %% [markdown]
# ### Random Forest Algo

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
model_rf = RandomForestClassifier(
    n_estimators=100,
      max_depth=5,
    random_state=42
)

# %%
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %%
train_score = model_rf.score(X_train, y_train)
test_score = model_rf.score(X_test, y_test)

print("Train Score:", train_score)
print("Test Score:", test_score)
# Out:
# Train Score: 0.7790406673618352
# Test Score: 0.7839866555462885

# %%
y_pred = model_rf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.99      0.87      1822
#            1       0.85      0.12      0.21       576
#
#     accuracy                           0.78      2398
#    macro avg       0.82      0.56      0.54      2398
# weighted avg       0.80      0.78      0.72      2398

# %% [markdown]
# ### try diffrent value on n_estimater for checking

# %%
for n in [50, 100, 150, 200]:
    model_rf = RandomForestClassifier(
        n_estimators=n,
        random_state=42
    )

    model_rf.fit(X_train, y_train)

    test_score = model_rf.score(X_test, y_test)

    print("Trees:", n, "Test Score:", test_score)
# Out:
# Trees: 50 Test Score: 0.7839866555462885
# Trees: 100 Test Score: 0.7844036697247706
# Trees: 150 Test Score: 0.7844036697247706
# Trees: 200 Test Score: 0.7844036697247706

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(
    n_estimators=50,
    learning_rate=1.0,
    random_state=42
)

# %%
ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
train_score = ada.score(X_train, y_train)

print("Train Score:", train_score)
# Out:
# Train Score: 0.7771637122002085

# %%
test_score = ada.score(X_test, y_test)

print("Test Score:", test_score)
# Out:
# Test Score: 0.7839866555462885

# %%
y_pred_ada = ada.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("AdaBoost Accuracy:", accuracy)
# Out:
# AdaBoost Accuracy: 0.7839866555462885

# %%
print(classification_report(y_test, y_pred_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.99      0.87      1822
#            1       0.85      0.12      0.21       576
#
#     accuracy                           0.78      2398
#    macro avg       0.82      0.56      0.54      2398
# weighted avg       0.80      0.78      0.72      2398

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# 1. Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 2. KNN Model (n_jobs=1 prevents the subprocess/wmic error on Windows)
knn_model = KNeighborsClassifier(n_neighbors=5, n_jobs=1)

# 3. Train Model
knn_model.fit(X_train_scaled, y_train)

# 4. Accuracy Evaluation
train_score = knn_model.score(X_train_scaled, y_train)
test_score = knn_model.score(X_test_scaled, y_test)

print("Train Score:", train_score)
print("Test Score:", test_score)

# 5. Prediction
y_pred = knn_model.predict(X_test_scaled)

# 6. Classification Report & Confusion Matrix
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Train Score: 0.7905109489051095
# Test Score: 0.7097581317764804
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83      1822
#            1       0.24      0.09      0.13       576
#
#     accuracy                           0.71      2398
#    macro avg       0.50      0.50      0.48      2398
# weighted avg       0.63      0.71      0.66      2398
#
#
# Confusion Matrix:
# [[1648  174]
#  [ 522   54]]
